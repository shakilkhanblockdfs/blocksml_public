# %%
sentence =  "How how are you doing, let see if this makes sence. I will encoding this"

# %%
sentence_List = sentence.split()

# %%
sentence_List
# Out:
# ['How',
#  'how',
#  'are',
#  'you',
#  'doing,',
#  'let',
#  'see',
#  'if',
#  'this',
#  'makes',
#  'sence.',
#  'I',
#  'will',
#  'encoding',
#  'this']

# %%
vocab = {word:idx for word,idx in enumerate(sentence_List)}

# %%
vocab
# Out:
# {0: 'How',
#  1: 'how',
#  2: 'are',
#  3: 'you',
#  4: 'doing,',
#  5: 'let',
#  6: 'see',
#  7: 'if',
#  8: 'this',
#  9: 'makes',
#  10: 'sence.',
#  11: 'I',
#  12: 'will',
#  13: 'encoding',
#  14: 'this'}

# %%
class tokenizer:
    def __init__(self, vocab):
        self.vocab = vocab
    def encode(self, sentence):
        return [self.vocab[word] for word in sentence.split()]

# %%
t = tokenizer(vocab)
# print(t.encode("How"))

# %%
vocab
# Out:
# {0: 'How',
#  1: 'how',
#  2: 'are',
#  3: 'you',
#  4: 'doing,',
#  5: 'let',
#  6: 'see',
#  7: 'if',
#  8: 'this',
#  9: 'makes',
#  10: 'sence.',
#  11: 'I',
#  12: 'will',
#  13: 'encoding',
#  14: 'this'}
